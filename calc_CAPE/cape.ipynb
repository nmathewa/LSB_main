# %%
from dask_jobqueue import SLURMCluster

cluster = SLURMCluster(
    job_name="Climt2",          # --job-name
    cores=2,                     # Number of cores per task (adjust if needed)
    processes=2,                 # One process per task
    memory="20GB",               # --mem
    walltime="00:15:00",         # --time
    queue="short",               # --partition
    log_directory=".",           # Logs will be saved to the current directory
)

import glob 
import os
# Out:
# /home1/nalex2023/.conda/envs/nma/lib/python3.13/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 42343 instead
#   warnings.warn(

# %%
from dask.distributed import Client

cluster.scale(jobs=10)
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://10.42.239.61:35955' processes=0 threads=0, memory=0 B>

# %%
data_dir = '/home1/nalex2023/Datasets/interpsonde_manus/*.nc'

all_dsets = glob.glob(data_dir)

all_dsets
# Out:
# ['/home1/nalex2023/Datasets/interpsonde_manus/2009_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2002_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2003_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2008_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2014_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2001_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2004_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2013_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2012_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2005_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2010_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2007_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2006_MANUS_INTERPSONDEv2.nc',
#  '/home1/nalex2023/Datasets/interpsonde_manus/2011_MANUS_INTERPSONDEv2.nc']

# %%
import xarray as xr 
import pandas as pd
import numpy as np

dset = xr.open_mfdataset(all_dsets, combine='by_coords')
dset['time'] = dset['time'] + pd.Timedelta('10 hour')

# %%
dset_sub = dset.sel(height=slice(0,8)).interpolate_na()

# %%
from metpy.calc import cape_cin, parcel_profile
from metpy.units import units

dset_sub['dp'] = dset_sub['dp'] * units.degC
dset_sub['temp'] = dset_sub['temp'] * units.degC
dset_sub['bar_pres'] = dset_sub['bar_pres'] * units('kPa')

# %%
dset_sub['dp'].plot()
# Out:
# /home1/nalex2023/.conda/envs/nma/lib/python3.13/site-packages/xarray/namedarray/pycompat.py:119: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   data = np.asarray(data)

# %%
#parcel_pro = parcel_profile(pres, temp[0], dew_point[0]).to('degC')

# apply the profile over each timestep

def calc_profile(temp, dew_point, pres):
    bottom_temp = temp[0]
    bottom_dp = dew_point[0]
    return parcel_profile(pres, bottom_temp, bottom_dp).to('degC')

parcel_profile = dset_sub.groupby('time').apply(lambda x: calc_profile(x['temp'], x['dp'], x['bar_pres'])).compute()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 10
#       7     bottom_dp = dew_point[0]
#       8     return parcel_profile(pres, bottom_temp, bottom_dp).to('degC')
# ---> 10 parcel_profile = dset_sub.groupby('time').apply(lambda x: calc_profile(x['temp'], x['dp'], x['bar_pres'])).compute()
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/core/groupby.py:1686, in DatasetGroupByBase.apply(self, func, args, shortcut, **kwargs)
#    1673 """
#    1674 Backward compatible implementation of ``map``
#    1675
#    (...)
#    1678 DatasetGroupBy.map
#    1679 """
#    1681 warnings.warn(
#    1682     "GroupBy.apply may be deprecated in the future. Using GroupBy.map is encouraged",
#    1683     PendingDeprecationWarning,
#    1684     stacklevel=2,
#    1685 )
# -> 1686 return self.map(func, shortcut=shortcut, args=args, **kwargs)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/core/groupby.py:1670, in DatasetGroupByBase.map(self, func, args, shortcut, **kwargs)
#    1668 # ignore shortcut if set (for now)
#    1669 applied = (func(ds, *args, **kwargs) for ds in self._iter_grouped())
# -> 1670 return self._combine(applied)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/core/groupby.py:1690, in DatasetGroupByBase._combine(self, applied)
#    1688 def _combine(self, applied):
#    1689     """Recombine the applied objects like the original."""
# -> 1690     applied_example, applied = peek_at(applied)
#    1691     dim, positions = self._infer_concat_args(applied_example)
#    1692     combined = concat(applied, dim)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/core/utils.py:199, in peek_at(iterable)
#     195 """Returns the first value from iterable, as well as a new iterator with
#     196 the same content as the original iterable
#     197 """
#     198 gen = iter(iterable)
# --> 199 peek = next(gen)
#     200 return peek, itertools.chain([peek], gen)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/core/groupby.py:1669, in <genexpr>(.0)
#    1639 """Apply a function to each Dataset in the group and concatenate them
#    1640 together into a new Dataset.
#    1641
#    (...)
#    1666     The result of splitting, applying and combining this dataset.
#    1667 """
#    1668 # ignore shortcut if set (for now)
# -> 1669 applied = (func(ds, *args, **kwargs) for ds in self._iter_grouped())
#    1670 return self._combine(applied)
#
# Cell In[82], line 10, in <lambda>(x)
#       7     bottom_dp = dew_point[0]
#       8     return parcel_profile(pres, bottom_temp, bottom_dp).to('degC')
# ---> 10 parcel_profile = dset_sub.groupby('time').apply(lambda x: calc_profile(x['temp'], x['dp'], x['bar_pres'])).compute()
#
# Cell In[82], line 8, in calc_profile(temp, dew_point, pres)
#       6 bottom_temp = temp[0]
#       7 bottom_dp = dew_point[0]
# ----> 8 return parcel_profile(pres, bottom_temp, bottom_dp).to('degC')
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/metpy/xarray.py:1330, in preprocess_and_wrap.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1327     _mutate_arguments(bound_args, units.Quantity, lambda arg, _: arg.m)
#    1329 # Evaluate inner calculation
# -> 1330 result = func(*bound_args.args, **bound_args.kwargs)
#    1332 # Wrap output based on match and match_unit
#    1333 if match is None:
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/metpy/units.py:333, in check_units.<locals>.dec.<locals>.wrapper(*args, **kwargs)
#     330 @functools.wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332     _check_units_inner_helper(func, sig, defaults, dims, *args, **kwargs)
# --> 333     return func(*args, **kwargs)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/metpy/calc/thermo.py:998, in parcel_profile(pressure, temperature, dewpoint)
#     924 @exporter.export
#     925 @preprocess_and_wrap(wrap_like='pressure')
#     926 @check_units('[pressure]', '[temperature]', '[temperature]')
#     927 def parcel_profile(pressure, temperature, dewpoint):
#     928     r"""Calculate the profile a parcel takes through the atmosphere.
#     929
#     930     The parcel starts at `temperature`, and `dewpoint`, lifted up
#    (...)
#     996
#     997     """
# --> 998     _, _, _, t_l, _, t_u = _parcel_profile_helper(pressure, temperature, dewpoint)
#     999     return concatenate((t_l, t_u))
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/metpy/calc/thermo.py:1191, in _parcel_profile_helper(pressure, temperature, dewpoint)
#    1188 _check_pressure_error(pressure)
#    1190 # Find the LCL
# -> 1191 press_lcl, temp_lcl = lcl(pressure[0], temperature, dewpoint)
#    1192 press_lcl = press_lcl.to(pressure.units)
#    1194 # Find the dry adiabatic profile, *including* the LCL. We need >= the LCL in case the
#    1195 # LCL is included in the levels. It's slightly redundant in that case, but simplifies
#    1196 # the logic for removing it later.
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/metpy/xarray.py:1330, in preprocess_and_wrap.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1327     _mutate_arguments(bound_args, units.Quantity, lambda arg, _: arg.m)
#    1329 # Evaluate inner calculation
# -> 1330 result = func(*bound_args.args, **bound_args.kwargs)
#    1332 # Wrap output based on match and match_unit
#    1333 if match is None:
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/metpy/units.py:389, in process_units.<locals>.dec.<locals>.wrapper(*args, **kwargs)
#     386 _mutate_arguments(bound_args, units.Quantity, lambda val, _: val.to_base_units().m)
#     388 # Evaluate inner calculation
# --> 389 result = func(*bound_args.args, **bound_args.kwargs)
#     391 # Wrap output
#     392 if multiple_output:
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/metpy/calc/thermo.py:480, in lcl(pressure, temperature, dewpoint, max_iters, eps)
#     478 nan_mask = False
#     479 w = mixing_ratio._nounit(saturation_vapor_pressure._nounit(dewpoint), pressure)
# --> 480 lcl_p = so.fixed_point(_lcl_iter, pressure, args=(pressure, w, temperature),
#     481                        xtol=eps, maxiter=max_iters)
#     482 lcl_p = np.where(nan_mask, np.nan, lcl_p)
#     484 # np.isclose needed if surface is LCL due to precision error with np.log in dewpoint.
#     485 # Causes issues with parcel_profile_with_lcl if removed. Issue #1187
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/scipy/optimize/_minpack_py.py:1170, in fixed_point(func, x0, args, xtol, maxiter, method)
#    1128 """
#    1129 Find a fixed point of the function.
#    1130
#    (...)
#    1167
#    1168 """
#    1169 use_accel = {'del2': True, 'iteration': False}[method]
# -> 1170 x0 = _asarray_validated(x0, as_inexact=True)
#    1171 return _fixed_point_helper(func, x0, args, xtol, maxiter, use_accel)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/scipy/_lib/_util.py:537, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     535         raise ValueError('masked arrays are not supported')
#     536 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 537 a = toarray(a)
#     538 if not objects_ok:
#     539     if a.dtype is np.dtype('O'):
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:646, in asarray_chkfinite(a, dtype, order)
#     644 a = asarray(a, dtype=dtype, order=order)
#     645 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 646     raise ValueError(
#     647         "array must not contain infs or NaNs")
#     648 return a
#
# ValueError: array must not contain infs or NaNs

# %%
client.close()
