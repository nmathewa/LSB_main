# %%
from dask_jobqueue import SLURMCluster

cluster = SLURMCluster(
    job_name="Climt1",          # --job-name
    cores=12,                     # Number of cores per task (adjust if needed)
    processes=6,                 # One process per task
    memory="100GB",               # --mem
    walltime="01:15:00",         # --time
    queue="med",               # --partition
    log_directory=".",           # Logs will be saved to the current directory
)
# Out:
# /home1/nalex2023/.conda/envs/nma/lib/python3.13/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 44905 instead
#   warnings.warn(

# %%
from dask.distributed import Client


cluster.scale(jobs=10)
client = Client(cluster)

# %%
client
# Out:
# <Client: 'tcp://10.42.239.61:41185' processes=0 threads=0, memory=0 B>

# %%
import xarray as xr
import numpy as np
import glob
import pandas as pd
import os

# %%
#test_dset =  xr.open_dataset('Datasets/met_manus_yr/1997-2000.met_manus.nc')

def create_dft(in_dir,arm_data=True):
    files = glob.glob(in_dir+os.sep+'*.nc')
    if len(files) == 0:
        files = glob.glob(in_dir+os.sep+'*.cdf')
        if len(files) == 0:
            raise Exception('No files Found')
        else:
            pass
    else:
        pass
    
    dft = pd.DataFrame(files,columns=['filepath'])
    dft['filename'] = dft['filepath'].str.split(os.sep).str[-1]
    
    if arm_data:
        dft['datetime'] = pd.to_datetime(dft['filename'].str.split(
            '.',
            expand=True).iloc[:, 2] + dft['filename'].str.split(
                '.',  expand=True).iloc[:, 3],format='%Y%m%d%H%M%S')
    return dft


files_met = 'Datasets/met_manus/'

dft_met = create_dft(files_met).set_index('datetime').sort_index()

years = [2001]

dft_sub = dft_met.loc[str(years[0]):str(years[-1])]


dft_sub
# Out:
#                                                               filepath  \
# datetime
# 2001-01-01 00:00:01  Datasets/met_manus/twpmetC1.b1.20010101.000001...
# 2001-01-02 00:00:00  Datasets/met_manus/twpmetC1.b1.20010102.000000...
# 2001-01-03 00:00:01  Datasets/met_manus/twpmetC1.b1.20010103.000001...
# 2001-01-04 00:00:00  Datasets/met_manus/twpmetC1.b1.20010104.000000...
# 2001-01-05 00:00:00  Datasets/met_manus/twpmetC1.b1.20010105.000000...
# ...                                                                ...
# 2001-12-27 00:00:00  Datasets/met_manus/twpmetC1.b1.20011227.000000...
# 2001-12-28 00:00:00  Datasets/met_manus/twpmetC1.b1.20011228.000000...
# 2001-12-29 00:00:00  Datasets/met_manus/twpmetC1.b1.20011229.000000...
# 2001-12-30 00:00:00  Datasets/met_manus/twpmetC1.b1.20011230.000000...
# 2001-12-31 00:00:00  Datasets/met_manus/twpmetC1.b1.20011231.000000...
#
#                                             filename
# datetime
# 2001-01-01 00:00:01  twpmetC1.b1.20010101.000001.cdf
# 2001-01-02 00:00:00  twpmetC1.b1.20010102.000000.cdf
# 2001-01-03 00:00:01  twpmetC1.b1.20010103.000001.cdf
# 2001-01-04 00:00:00  twpmetC1.b1.20010104.000000.cdf
# 2001-01-05 00:00:00  twpmetC1.b1.20010105.000000.cdf
# ...                                              ...
# 2001-12-27 00:00:00  twpmetC1.b1.20011227.000000.cdf
# 2001-12-28 00:00:00  twpmetC1.b1.20011228.000000.cdf
# 2001-12-29 00:00:00  twpmetC1.b1.20011229.000000.cdf
# 2001-12-30 00:00:00  twpmetC1.b1.20011230.000000.cdf
# 2001-12-31 00:00:00  twpmetC1.b1.20011231.000000.cdf
#
# [365 rows x 2 columns]

# %%
all_dset = xr.open_mfdataset(dft_sub['filepath'].values,combine='by_coords',
                             chunks={})

all_dset['time'] = all_dset['time'] + pd.to_timedelta(10,'h')

# %%
all_dset
# Out:
# <xarray.Dataset> Size: 138MB
# Dimensions:                  (time: 521090)
# Coordinates:
#   * time                     (time) datetime64[ns] 4MB 2001-01-01T10:00:01 .....
# Data variables: (12/45)
#     base_time                (time) datetime64[ns] 4MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     time_offset              (time) datetime64[ns] 4MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     atmos_pressure           (time) float32 2MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     qc_atmos_pressure        (time) float64 4MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     temp_mean                (time) float32 2MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     qc_temp_mean             (time) float64 4MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     ...                       ...
#     qc_logger_volt           (time) float64 4MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     logger_temp              (time) float32 2MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     qc_logger_temp           (time) float64 4MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     lat                      (time) float32 2MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     lon                      (time) float32 2MB dask.array<chunksize=(1440,), meta=np.ndarray>
#     alt                      (time) float32 2MB dask.array<chunksize=(1440,), meta=np.ndarray>
# Attributes: (12/30)
#     command_line:                met_ingest -s twp -f C1 -R -D
#     process_version:             ingest-met-4.28-0.el6
#     dod_version:                 met-b1-8.1
#     input_source:                /data/home/gervais/prod/jobs/0742/collection...
#     site_id:                     twp
#     platform_id:                 met
#     ...                          ...
#     qc_bit_2_assessment:         Bad
#     qc_bit_3_description:        Value is greater than the valid_max.
#     qc_bit_3_assessment:         Bad
#     qc_bit_4_description:        Difference between current and previous valu...
#     qc_bit_4_assessment:         Indeterminate
#     history:                     created by user gervais on machine amber at ...

# %%
# remove values greater than 50

all_dset = all_dset.where(all_dset['qc_temp_mean'] == 0)

all_dset = all_dset.where(all_dset['qc_rh_mean'] == 0)


all_dset = all_dset.where(all_dset['qc_wspd_arith_mean'] == 0)

all_dset = all_dset.where(all_dset['qc_wdir_vec_mean'] == 0)


all_dset_diurnal = all_dset.groupby('time.hour').mean()

# %%
computed_dset = all_dset_diurnal.compute()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 computed_dset = all_dset_diurnal.compute()
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/core/dataset.py:1072, in Dataset.compute(self, **kwargs)
#    1048 """Manually trigger loading and/or computation of this dataset's data
#    1049 from disk or a remote source into memory and return a new dataset.
#    1050 Unlike load, the original dataset is left unaltered.
#    (...)
#    1069 dask.compute
#    1070 """
#    1071 new = self.copy(deep=False)
# -> 1072 return new.load(**kwargs)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/core/dataset.py:899, in Dataset.load(self, **kwargs)
#     896 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     898 # evaluate all the chunked arrays simultaneously
# --> 899 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     900     *lazy_data.values(), **kwargs
#     901 )
#     903 for k, data in zip(lazy_data, evaluated_data, strict=False):
#     904     self.variables[k].data = data
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/namedarray/daskmanager.py:85, in DaskManager.compute(self, *data, **kwargs)
#      80 def compute(
#      81     self, *data: Any, **kwargs: Any
#      82 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      83     from dask.array import compute
# ---> 85     return compute(*data, **kwargs)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/base.py:653, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     645     return args
#     647 schedule = get_scheduler(
#     648     scheduler=scheduler,
#     649     collections=collections,
#     650     get=get,
#     651 )
# --> 653 dsk = collections_to_dsk(collections, optimize_graph, **kwargs)
#     654 keys, postcomputes = [], []
#     655 for x in collections:
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/base.py:422, in collections_to_dsk(collections, optimize_graph, optimizations, **kwargs)
#     420 for opt, val in groups.items():
#     421     dsk, keys = _extract_graph_and_keys(val)
# --> 422     dsk = opt(dsk, keys, **kwargs)
#     424     for opt_inner in optimizations:
#     425         dsk = opt_inner(dsk, keys, **kwargs)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/array/optimization.py:36, in optimize(dsk, keys, **kwargs)
#      33 if config.get("optimization.fuse.active") is False:
#      34     return dsk
# ---> 36 dsk = ensure_dict(dsk)
#      38 dsk = convert_legacy_graph(dsk)
#      39 dsk = fuse_linear_task_spec(dsk, keys=keys)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/utils.py:1390, in ensure_dict(d, copy)
#    1388 result = {}
#    1389 for layer in toolz.unique(layers.values(), key=id):
# -> 1390     result.update(layer)
#    1391 return result
#
# File <frozen _collections_abc>:874, in __iter__(self)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/blockwise.py:641, in Blockwise.__iter__(self)
#     640 def __iter__(self):
# --> 641     return iter(self._dict)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/blockwise.py:607, in Blockwise._dict(self)
#     604 else:
#     605     keys = tuple(map(blockwise_token, range(len(self.indices))))
# --> 607     dsk = _make_blockwise_graph(
#     608         self.task,
#     609         self.output,
#     610         self.output_indices,
#     611         *list(toolz.concat(self.indices)),
#     612         new_axes=self.new_axes,
#     613         numblocks=self.numblocks,
#     614         concatenate=self.concatenate,
#     615         output_blocks=self.output_blocks,
#     616         dims=self.dims,
#     617         io_deps=self.io_deps,
#     618         keys=keys,
#     619     )
#     621     self._cached_dict = {"dsk": dsk}
#     622 return self._cached_dict["dsk"]
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/blockwise.py:994, in _make_blockwise_graph(task, output, out_indices, numblocks, concatenate, new_axes, output_blocks, dims, io_deps, keys, *arrind_pairs)
#     992         else:
#     993             subs[key] = (arg, *arg_coords)
# --> 994         this_task = this_task.substitute(subs)
#     995 new_key = (output,) + out_coords
#     996 assert isinstance(this_task, Task)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/_task_spec.py:766, in Task.substitute(self, subs, key)
#     762 subs_filtered = {
#     763     k: v for k, v in subs.items() if k in self.dependencies and k != v
#     764 }
#     765 if subs_filtered:
# --> 766     new_args = tuple(
#     767         a.substitute(subs_filtered) if isinstance(a, GraphNode) else a
#     768         for a in self.args
#     769     )
#     770     new_kwargs = {
#     771         k: v.substitute(subs_filtered) if isinstance(v, GraphNode) else v
#     772         for k, v in self.kwargs.items()
#     773     }
#     774     return type(self)(
#     775         key or self.key,
#     776         self.func,
#     777         *new_args,
#     778         **new_kwargs,
#     779     )
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/_task_spec.py:767, in <genexpr>(.0)
#     762 subs_filtered = {
#     763     k: v for k, v in subs.items() if k in self.dependencies and k != v
#     764 }
#     765 if subs_filtered:
#     766     new_args = tuple(
# --> 767         a.substitute(subs_filtered) if isinstance(a, GraphNode) else a
#     768         for a in self.args
#     769     )
#     770     new_kwargs = {
#     771         k: v.substitute(subs_filtered) if isinstance(v, GraphNode) else v
#     772         for k, v in self.kwargs.items()
#     773     }
#     774     return type(self)(
#     775         key or self.key,
#     776         self.func,
#     777         *new_args,
#     778         **new_kwargs,
#     779     )
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/_task_spec.py:891, in Dict.substitute(self, subs, key)
#     889     k, v = tup.substitute(subs_filtered).args
#     890     new[k] = v
# --> 891 return type(self)(new)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/_task_spec.py:870, in Dict.__init__(self, _dependencies, *args, **kwargs)
#     868         raise ValueError("Dict can only take one positional argument")
#     869     kwargs = args[0]
# --> 870 super().__init__(
#     871     *(Tuple(*it) for it in kwargs.items()), _dependencies=_dependencies
#     872 )
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/_task_spec.py:871, in <genexpr>(.0)
#     868         raise ValueError("Dict can only take one positional argument")
#     869     kwargs = args[0]
#     870 super().__init__(
# --> 871     *(Tuple(*it) for it in kwargs.items()), _dependencies=_dependencies
#     872 )
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/dask/_task_spec.py:805, in NestedContainer.__init__(self, _dependencies, *args, **kwargs)
#     803 if len(args) == 1 and isinstance(args[0], self.klass):
#     804     args = args[0]  # type: ignore
# --> 805 super().__init__(
#     806     None,
#     807     self.to_container,
#     808     *args,
#     809     klass=self.klass,
#     810     _dependencies=_dependencies,
#     811     **kwargs,
#     812 )
#
# KeyboardInterrupt:

# %%
computed_dset

# %%
from windrose import WindroseAxes


ax = WindroseAxes.from_ax()

wspd = all_dset_diurnal['wspd_arith_mean'].sel(hour=15).values

wdir = all_dset_diurnal['wdir_vec_mean'].sel(hour=15).values


ax.bar(wdir, wspd, normed=True, opening=0.8, edgecolor='white')

#all_dset_diurnal['wdir_vec_mean'].plot.line(x='hour')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 11
#       6 wspd = all_dset_diurnal['wspd_arith_mean'].sel(hour=15).values
#       8 wdir = all_dset_diurnal['wdir_vec_mean'].sel(hour=15).values
# ---> 11 ax.bar(wdir, wspd, normed=True, opening=0.8, edgecolor='white')
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/windrose/windrose.py:639, in WindroseAxes.bar(self, direction, var, **kwargs)
#     589 def bar(self, direction, var, **kwargs):
#     590     """
#     591     Plot a windrose in bar mode. For each var bins and for each sector,
#     592     a colored bar will be draw on the axes.
#    (...)
#     636
#     637     """
# --> 639     bins, nbins, nsector, colors, angles, kwargs = self._init_plot(
#     640         direction,
#     641         var,
#     642         **kwargs,
#     643     )
#     644     kwargs.pop("facecolor", None)
#     645     edgecolor = kwargs.pop("edgecolor", None)
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/windrose/windrose.py:318, in WindroseAxes._init_plot(self, direction, var, **kwargs)
#     316 # Calm condition, mask data if needed
#     317 calm_limit = kwargs.pop("calm_limit", None)
# --> 318 total = len(var)
#     319 if calm_limit is not None:
#     320     mask = var > calm_limit
#
# TypeError: len() of unsized object

# %%
from dask.diagnostics import ProgressBar
import dask 

def prepro(ds):
    list_vars = ['wdir_vec_mean', 'wspd_vec_mean', 'rh_mean', 'temp_mean']
    ds_sub = ds[list_vars]
    ds_re = ds_sub.resample(time='1H').mean()
    return ds_re


years = [year for year in dft_met.index.year.unique()]

years

save_tasks = [] 
for ii in years:
    dft_sub = (dft_met[dft_met.index.year == ii]).sort_index()
    dset = xr.open_mfdataset(dft_sub['filepath'].values,preprocess=prepro,parallel=True,chunks={},combine='by_coords')
    out_fol = f'Datasets/met_manus_yr/met_manus_{ii}.nc'

    save_tasks.append(dset.to_netcdf(out_fol,compute=False))
    #dset.to_netcdf(out_fol)

with ProgressBar():
    results = dask.compute(*save_tasks)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 18
#      16 for ii in years:
#      17     dft_sub = (dft_met[dft_met.index.year == ii]).sort_index()
# ---> 18     dset = xr.open_mfdataset(dft_sub['filepath'].values,preprocess=prepro,parallel=True,chunks={},combine='by_coords')
#      19     out_fol = f'Datasets/met_manus_yr/met_manus_{ii}.nc'
#      21     save_tasks.append(dset.to_netcdf(out_fol,compute=False))
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/backends/api.py:1607, in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#    1594     combined = _nested_combine(
#    1595         datasets,
#    1596         concat_dims=concat_dim,
#    (...)
#    1602         combine_attrs=combine_attrs,
#    1603     )
#    1604 elif combine == "by_coords":
#    1605     # Redo ordering from coordinates, ignoring how they were ordered
#    1606     # previously
# -> 1607     combined = combine_by_coords(
#    1608         datasets,
#    1609         compat=compat,
#    1610         data_vars=data_vars,
#    1611         coords=coords,
#    1612         join=join,
#    1613         combine_attrs=combine_attrs,
#    1614     )
#    1615 else:
#    1616     raise ValueError(
#    1617         f"{combine} is an invalid option for the keyword argument"
#    1618         " ``combine``"
#    1619     )
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/core/combine.py:973, in combine_by_coords(data_objects, compat, data_vars, coords, fill_value, join, combine_attrs)
#     969     grouped_by_vars = itertools.groupby(sorted_datasets, key=vars_as_keys)
#     971     # Perform the multidimensional combine on each group of data variables
#     972     # before merging back together
# --> 973     concatenated_grouped_by_data_vars = tuple(
#     974         _combine_single_variable_hypercube(
#     975             tuple(datasets_with_same_vars),
#     976             fill_value=fill_value,
#     977             data_vars=data_vars,
#     978             coords=coords,
#     979             compat=compat,
#     980             join=join,
#     981             combine_attrs=combine_attrs,
#     982         )
#     983         for vars, datasets_with_same_vars in grouped_by_vars
#     984     )
#     986 return merge(
#     987     concatenated_grouped_by_data_vars,
#     988     compat=compat,
#    (...)
#     991     combine_attrs=combine_attrs,
#     992 )
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/core/combine.py:974, in <genexpr>(.0)
#     969     grouped_by_vars = itertools.groupby(sorted_datasets, key=vars_as_keys)
#     971     # Perform the multidimensional combine on each group of data variables
#     972     # before merging back together
#     973     concatenated_grouped_by_data_vars = tuple(
# --> 974         _combine_single_variable_hypercube(
#     975             tuple(datasets_with_same_vars),
#     976             fill_value=fill_value,
#     977             data_vars=data_vars,
#     978             coords=coords,
#     979             compat=compat,
#     980             join=join,
#     981             combine_attrs=combine_attrs,
#     982         )
#     983         for vars, datasets_with_same_vars in grouped_by_vars
#     984     )
#     986 return merge(
#     987     concatenated_grouped_by_data_vars,
#     988     compat=compat,
#    (...)
#     991     combine_attrs=combine_attrs,
#     992 )
#
# File ~/.conda/envs/nma/lib/python3.13/site-packages/xarray/core/combine.py:660, in _combine_single_variable_hypercube(datasets, fill_value, data_vars, coords, compat, join, combine_attrs)
#     658     indexes = concatenated.indexes.get(dim)
#     659     if not (indexes.is_monotonic_increasing or indexes.is_monotonic_decreasing):
# --> 660         raise ValueError(
#     661             "Resulting object does not have monotonic"
#     662             f" global indexes along dimension {dim}"
#     663         )
#     665 return concatenated
#
# ValueError: Resulting object does not have monotonic global indexes along dimension time

# %%
client.close()

cluster.close()
